# %% [markdown]
# # 모두의 딥러닝 책 예제코드 실행

# %% [markdown]
# 4. 오차 수정하기: 경사 하강법

# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

# %%
# x,y 데이터 값
data = [[2,81],[4,93],[6,91],[8,97]]
x_data = [x_row[0] for x_row in data]
y_data = [y_row[1] for y_row in data]

print(x_data, y_data)
# Out:
# [2, 4, 6, 8] [81, 93, 91, 97]

# %%
# 기울기 a와 y절편 b의 값을 임의로 정한다.
# 단, 기울기 범위는 0~10 사이며, y 절편은 0~100 사이에서 변하게 한다.
a = tf.Variable(tf.compat.v1.random_uniform([1], 0, 10, dtype=tf.float64, seed=0))
b = tf.Variable(tf.compat.v1.random_uniform([1], 0, 100, dtype=tf.float64, seed=0))

# %%
# y에 대한 일차 방정식 ax+b의 식을 세운다.
y=a*x_data + b

# %%
# tensorflow RMSE 함수
rmse=tf.sqrt(tf.reduce_mean(tf.square(y-y_data)))

# %%
# 학습률 값
learning_rate = 0.1

# %%
# RMSE 값을 최소로 하는 값 찾기
gradient_descent = tf.compat.v1.train.GradientDescentOptimizer(learning_rate).minimize(rmse)

# %%
# tensorflow 이용 학습
with tf.compat.v1.Session() as sess:
    # 변수 초기화
    sess.run(tf.compat.v1.global_variables_initializer())
    
    # 2001번 실행
    for step in range(20000):
        sess.run(gradient_descent)
        # 100번 마다 출력
        if step % 100 == 0:
            print("Epoch : {0}, RMSE : {1}, 기울기 : {2}, y 절편 : {3}".format(step, sess.run(rmse), sess.run(a), sess.run(b)))
# Out:
# Epoch : 0, RMSE : 30.213942199096312, 기울기 : [7.52346569], y 절편 : [80.59835907]
# Epoch : 100, RMSE : 2.8860236717777323, 기울기 : [2.22994555], y 절편 : [79.41805502]
# Epoch : 200, RMSE : 2.8826088464380675, 기울기 : [2.26013532], y 절편 : [79.23789538]
# Epoch : 300, RMSE : 2.881501758172984, 기울기 : [2.27732406], y 절편 : [79.13532033]
# Epoch : 400, RMSE : 2.881143413326604, 기울기 : [2.2871031], y 절편 : [79.0769632]
# Epoch : 500, RMSE : 2.8810274836268746, 기울기 : [2.29266522], y 절편 : [79.04377083]
# Epoch : 600, RMSE : 2.8809899850055283, 기울기 : [2.29582859], y 절편 : [79.02489319]
# Epoch : 700, RMSE : 2.8809778563604618, 기울기 : [2.29762766], y 절편 : [79.0141571]
# Epoch : 800, RMSE : 2.8809739335110462, 기울기 : [2.29865082], y 절편 : [79.00805133]
# Epoch : 900, RMSE : 2.8809726647246285, 기울기 : [2.2992327], y 절편 : [79.00457889]
# Epoch : 1000, RMSE : 2.880972254355579, 기울기 : [2.29956363], y 절편 : [79.00260407]
# Epoch : 1100, RMSE : 2.880972121628225, 기울기 : [2.29975183], y 절편 : [79.00148097]
# Epoch : 1200, RMSE : 2.88097207869968, 기울기 : [2.29985886], y 절편 : [79.00084225]
# Epoch : 1300, RMSE : 2.8809720648151282, 기울기 : [2.29991973], y 절편 : [79.000479]
# Epoch : 1400, RMSE : 2.880972060324397, 기울기 : [2.29995435], y 절편 : [79.00027241]
# Epoch : 1500, RMSE : 2.8809720588719343, 기울기 : [2.29997404], y 절편 : [79.00015492]
# Epoch : 1600, RMSE : 2.8809720584021608, 기울기 : [2.29998524], y 절편 : [79.00008811]
# Epoch : 1700, RMSE : 2.8809720582502196, 기울기 : [2.2999916], y 절편 : [79.00005011]
# Epoch : 1800, RMSE : 2.8809720582010825, 기울기 : [2.29999522], y 절편 : [79.0000285]
# Epoch : 1900, RMSE : 2.8809720581851854, 기울기 : [2.29999728], y 절편 : [79.00001621]
# Epoch : 2000, RMSE : 2.8809720581800415, 기울기 : [2.29999846], y 절편 : [79.00000922]
# Epoch : 2100, RMSE : 2.880972058178384, 기울기 : [2.29999912], y 절편 : [79.00000524]
# Epoch : 2200, RMSE : 2.8809720581778464, 기울기 : [2.2999995], y 절편 : [79.00000298]
# Epoch : 2300, RMSE : 2.88097205817767, 기울기 : [2.29999972], y 절편 : [79.0000017]
# Epoch : 2400, RMSE : 2.8809720581776164, 기울기 : [2.29999984], y 절편 : [79.00000096]
# Epoch : 2500, RMSE : 2.880972058177593, 기울기 : [2.29999991], y 절편 : [79.00000055]
# Epoch : 2600, RMSE : 2.8809720581775893, 기울기 : [2.29999995], y 절편 : [79.00000031]
# Epoch : 2700, RMSE : 2.880972058177588, 기울기 : [2.29999997], y 절편 : [79.00000018]
# Epoch : 2800, RMSE : 2.8809720581775897, 기울기 : [2.29999998], y 절편 : [79.0000001]
# Epoch : 2900, RMSE : 2.880972058177584, 기울기 : [2.29999999], y 절편 : [79.00000006]
# Epoch : 3000, RMSE : 2.880972058177587, 기울기 : [2.29999999], y 절편 : [79.00000003]
# Epoch : 3100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.00000002]
# Epoch : 3200, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.00000001]
# Epoch : 3300, RMSE : 2.8809720581775893, 기울기 : [2.3], y 절편 : [79.00000001]
# Epoch : 3400, RMSE : 2.8809720581775875, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 3500, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 3600, RMSE : 2.8809720581775897, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 3700, RMSE : 2.880972058177584, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 3800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 3900, RMSE : 2.880972058177584, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 4000, RMSE : 2.880972058177584, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 4100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 4200, RMSE : 2.8809720581775893, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 4300, RMSE : 2.8809720581775893, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 4400, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 4500, RMSE : 2.8809720581775893, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 4600, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 4700, RMSE : 2.880972058177584, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 4800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 4900, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 5000, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 5100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 5200, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 5300, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 5400, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 5500, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 5600, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 5700, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 5800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 5900, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 6000, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 6100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 6200, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 6300, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 6400, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 6500, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 6600, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 6700, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 6800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 6900, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 7000, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 7100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 7200, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 7300, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 7400, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 7500, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 7600, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 7700, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 7800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 7900, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 8000, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 8100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 8200, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 8300, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 8400, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 8500, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 8600, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 8700, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 8800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 8900, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 9000, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 9100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 9200, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 9300, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 9400, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 9500, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 9600, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 9700, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 9800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 9900, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 10000, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 10100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 10200, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 10300, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 10400, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 10500, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 10600, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 10700, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 10800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 10900, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 11000, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 11100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 11200, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 11300, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 11400, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 11500, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 11600, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 11700, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 11800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 11900, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 12000, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 12100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 12200, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 12300, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 12400, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 12500, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 12600, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 12700, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 12800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 12900, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 13000, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 13100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 13200, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 13300, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 13400, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 13500, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 13600, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 13700, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 13800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 13900, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 14000, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 14100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 14200, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 14300, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 14400, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 14500, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 14600, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 14700, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 14800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 14900, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 15000, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 15100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 15200, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 15300, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 15400, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 15500, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 15600, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 15700, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 15800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 15900, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 16000, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 16100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 16200, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 16300, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 16400, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 16500, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 16600, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 16700, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 16800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 16900, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 17000, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 17100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 17200, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 17300, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 17400, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 17500, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 17600, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 17700, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 17800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 17900, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 18000, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 18100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 18200, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 18300, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 18400, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 18500, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 18600, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 18700, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 18800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 18900, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 19000, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 19100, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 19200, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 19300, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 19400, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 19500, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 19600, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 19700, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 19800, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
# Epoch : 19900, RMSE : 2.8809720581775866, 기울기 : [2.3], y 절편 : [79.]
